# %% [markdown]
# ## Streaming Media Company Case Study

# %% [markdown]
# Problem Statement: A digital media company (similar to Voot, Hotstar, Netflix, etc.) had launched a show. Initially, the show got a good response, but then witnessed a decline in viewership. The company wants to figure out what went wrong.

# %%
# Importing all required packages
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
#Importing dataset
media = pd.read_csv('mediacompany.csv')
media = media.drop('Unnamed: 7',axis = 1)

# %%
#Let's explore the top 5 rows
media.head()
# Out:
#        Date  Views_show  Visitors  Views_platform  Ad_impression  \
# 0  3/1/2017      183738   1260228         1706478     1060860448
# 1  3/2/2017      193763   1270561         1690727     1031846645
# 2  3/3/2017      210479   1248183         1726157     1010867575
# 3  3/4/2017      240061   1492913         1855353     1079194579
# 4  3/5/2017      446314   1594712         2041418     1357736987
#
#    Cricket_match_india  Character_A
# 0                    0            0
# 1                    0            0
# 2                    0            0
# 3                    1            0
# 4                    0            0

# %%
# Converting date to Pandas datetime format
media['Date'] = pd.to_datetime(media['Date'])

# %%
media.head()
# Out:
#         Date  Views_show  Visitors  Views_platform  Ad_impression  \
# 0 2017-03-01      183738   1260228         1706478     1060860448
# 1 2017-03-02      193763   1270561         1690727     1031846645
# 2 2017-03-03      210479   1248183         1726157     1010867575
# 3 2017-03-04      240061   1492913         1855353     1079194579
# 4 2017-03-05      446314   1594712         2041418     1357736987
#
#    Cricket_match_india  Character_A
# 0                    0            0
# 1                    0            0
# 2                    0            0
# 3                    1            0
# 4                    0            0

# %%
media['day']=media['Date'].dt.dayofweek

# %%
media.head()
# Out:
#         Date  Views_show  Visitors  Views_platform  Ad_impression  \
# 0 2017-03-01      183738   1260228         1706478     1060860448
# 1 2017-03-02      193763   1270561         1690727     1031846645
# 2 2017-03-03      210479   1248183         1726157     1010867575
# 3 2017-03-04      240061   1492913         1855353     1079194579
# 4 2017-03-05      446314   1594712         2041418     1357736987
#
#    Cricket_match_india  Character_A  day
# 0                    0            0    2
# 1                    0            0    3
# 2                    0            0    4
# 3                    1            0    5
# 4                    0            0    6

# %%
# Cleaning days
media['day'] = media['day'].astype(str)
media['day'] = media['day'].map(lambda x: x[0:2])
media['day'] = media['day'].astype(int)

# %%
media.head()
# Out:
#         Date  Views_show  Visitors  Views_platform  Ad_impression  \
# 0 2017-03-01      183738   1260228         1706478     1060860448
# 1 2017-03-02      193763   1270561         1690727     1031846645
# 2 2017-03-03      210479   1248183         1726157     1010867575
# 3 2017-03-04      240061   1492913         1855353     1079194579
# 4 2017-03-05      446314   1594712         2041418     1357736987
#
#    Cricket_match_india  Character_A  day
# 0                    0            0    2
# 1                    0            0    3
# 2                    0            0    4
# 3                    1            0    5
# 4                    0            0    6

# %%
# days vs Views_show
media.plot.line(x='day', y='Views_show')

# %%
# Scatter Plot (days vs Views_show)
colors = (0,0,0)
area = np.pi*3
plt.scatter(media.day, media.Views_show, s=area, c=colors, alpha=0.5)
plt.title('Scatter plot pythonspot.com')
plt.xlabel('x')
plt.ylabel('y')
plt.show()
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.

# %%
# plot for days vs Views_show and days vs Ad_impressions

fig = plt.figure()
host = fig.add_subplot(111)

par1 = host.twinx()
par2 = host.twinx()

host.set_xlabel("Day")
host.set_ylabel("View_Show")
par1.set_ylabel("Ad_impression")

color1 = plt.cm.viridis(0)
color2 = plt.cm.viridis(0.5)
color3 = plt.cm.viridis(.9)

p1, = host.plot(media.day,media.Views_show, color=color1,label="View_Show")
p2, = par1.plot(media.day,media.Ad_impression,color=color2, label="Ad_impression")

lns = [p1, p2]
host.legend(handles=lns, loc='best')

# right, left, top, bottom
par2.spines['right'].set_position(('outward', 60))      
# no x-ticks                 
par2.xaxis.set_ticks([])
# Sometimes handy, same for xaxis
#par2.yaxis.set_ticks_position('right')

host.yaxis.label.set_color(p1.get_color())
par1.yaxis.label.set_color(p2.get_color())

plt.savefig("pyplot_multiple_y-axis.png", bbox_inches='tight')

# %%
# Derived Metrics
# Weekdays are taken such that 1 corresponds to Sunday and 7 to Saturday
# Generate the weekday variable
media['weekday'] = (media['day']+3)%7
media.weekday.replace(0,7, inplace=True)
media['weekday'] = media['weekday'].astype(int)
media.head()
# Out:
#         Date  Views_show  Visitors  Views_platform  Ad_impression  \
# 0 2017-03-01      183738   1260228         1706478     1060860448
# 1 2017-03-02      193763   1270561         1690727     1031846645
# 2 2017-03-03      210479   1248183         1726157     1010867575
# 3 2017-03-04      240061   1492913         1855353     1079194579
# 4 2017-03-05      446314   1594712         2041418     1357736987
#
#    Cricket_match_india  Character_A  day  weekday
# 0                    0            0    2        5
# 1                    0            0    3        6
# 2                    0            0    4        7
# 3                    1            0    5        1
# 4                    0            0    6        2

# %% [markdown]
# #### Running first model (lm1) Weekday & visitors

# %%
# Putting feature variable to X
X = media[['Visitors','weekday']]

# Putting response variable to y
y = media['Views_show']

# %%
from sklearn.linear_model import LinearRegression

# %%
# Representing LinearRegression as lr(Creating LinearRegression Object)
lm = LinearRegression()

# %%
# fit the model to the training data
lm.fit(X,y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
import statsmodels.api as sm
#Unlike SKLearn, statsmodels don't automatically fit a constant, 
#so you need to use the method sm.add_constant(X) in order to add a constant. 
X = sm.add_constant(X)
# create a fitted model in one line
lm_1 = sm.OLS(y,X).fit()
print(lm_1.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             Views_show   R-squared:                       0.472
# Model:                            OLS   Adj. R-squared:                  0.459
# Method:                 Least Squares   F-statistic:                     34.48
# Date:                Thu, 30 Apr 2020   Prob (F-statistic):           2.03e-11
# Time:                        21:32:51   Log-Likelihood:                -1043.5
# No. Observations:                  80   AIC:                             2093.
# Df Residuals:                      77   BIC:                             2100.
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       7.762e+04   1.22e+05      0.637      0.526   -1.65e+05     3.2e+05
# Visitors       0.2138      0.062      3.445      0.001       0.090       0.337
# weekday    -3.704e+04   7110.982     -5.209      0.000   -5.12e+04   -2.29e+04
# ==============================================================================
# Omnibus:                        4.605   Durbin-Watson:                   1.776
# Prob(Omnibus):                  0.100   Jarque-Bera (JB):                4.319
# Skew:                           0.569   Prob(JB):                        0.115
# Kurtosis:                       2.992   Cond. No.                     1.64e+07
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.64e+07. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
# create Weekend variable, with value 1 at weekends and 0 at weekdays
def cond(i):
    if i % 7 == 5: return 1
    elif i % 7 == 4: return 1
    else :return 0
    return i

media['weekend']=[cond(i) for i in media['day']]

# %%
media.head()
# Out:
#         Date  Views_show  Visitors  Views_platform  Ad_impression  \
# 0 2017-03-01      183738   1260228         1706478     1060860448
# 1 2017-03-02      193763   1270561         1690727     1031846645
# 2 2017-03-03      210479   1248183         1726157     1010867575
# 3 2017-03-04      240061   1492913         1855353     1079194579
# 4 2017-03-05      446314   1594712         2041418     1357736987
#
#    Cricket_match_india  Character_A  day  weekday  weekend
# 0                    0            0    2        5        0
# 1                    0            0    3        6        0
# 2                    0            0    4        7        1
# 3                    1            0    5        1        1
# 4                    0            0    6        2        0

# %% [markdown]
# #### Running second model (lm2) visitors & weekend

# %%
# Putting feature variable to X
X = media[['Visitors','weekend']]

# Putting response variable to y
y = media['Views_show']

# %%
import statsmodels.api as sm
#Unlike SKLearn, statsmodels don't automatically fit a constant, 
#so you need to use the method sm.add_constant(X) in order to add a constant. 
X = sm.add_constant(X)
# create a fitted model in one line
lm_2 = sm.OLS(y,X).fit()
print(lm_2.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             Views_show   R-squared:                       0.313
# Model:                            OLS   Adj. R-squared:                  0.295
# Method:                 Least Squares   F-statistic:                     17.54
# Date:                Thu, 30 Apr 2020   Prob (F-statistic):           5.28e-07
# Time:                        21:32:53   Log-Likelihood:                -1054.1
# No. Observations:                  80   AIC:                             2114.
# Df Residuals:                      77   BIC:                             2121.
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const      -2.969e+05   1.09e+05     -2.715      0.008   -5.15e+05   -7.92e+04
# Visitors       0.3547      0.063      5.600      0.000       0.229       0.481
# weekend    -5.537e+04   3.22e+04     -1.722      0.089   -1.19e+05    8654.472
# ==============================================================================
# Omnibus:                        3.592   Durbin-Watson:                   0.779
# Prob(Omnibus):                  0.166   Jarque-Bera (JB):                3.567
# Skew:                           0.490   Prob(JB):                        0.168
# Kurtosis:                       2.670   Cond. No.                     1.29e+07
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.29e+07. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# #### Running third model (lm3) visitors, weekend & Character_A

# %%
# Putting feature variable to X
X = media[['Visitors','weekend','Character_A']]

# Putting response variable to y
y = media['Views_show']

# %%
import statsmodels.api as sm
#Unlike SKLearn, statsmodels don't automatically fit a constant, 
#so you need to use the method sm.add_constant(X) in order to add a constant. 
X = sm.add_constant(X)
# create a fitted model in one line
lm_3 = sm.OLS(y,X).fit()
print(lm_3.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             Views_show   R-squared:                       0.400
# Model:                            OLS   Adj. R-squared:                  0.377
# Method:                 Least Squares   F-statistic:                     16.91
# Date:                Thu, 30 Apr 2020   Prob (F-statistic):           1.65e-08
# Time:                        21:32:55   Log-Likelihood:                -1048.6
# No. Observations:                  80   AIC:                             2105.
# Df Residuals:                      76   BIC:                             2115.
# Df Model:                           3
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# const       -2.548e+05   1.04e+05     -2.459      0.016   -4.61e+05   -4.84e+04
# Visitors        0.3092      0.061      5.058      0.000       0.187       0.431
# weekend     -5.843e+04   3.02e+04     -1.931      0.057   -1.19e+05    1820.667
# Character_A  9.645e+04    2.9e+04      3.327      0.001    3.87e+04    1.54e+05
# ==============================================================================
# Omnibus:                        4.095   Durbin-Watson:                   0.942
# Prob(Omnibus):                  0.129   Jarque-Bera (JB):                3.677
# Skew:                           0.444   Prob(JB):                        0.159
# Kurtosis:                       2.438   Cond. No.                     1.30e+07
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.3e+07. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
# Create lag variable
media['Lag_Views'] = np.roll(media['Views_show'], 1)
media.Lag_Views.replace(108961,0, inplace=True)

# %%
media.head(10)
# Out:
#         Date  Views_show  Visitors  Views_platform  Ad_impression  \
# 0 2017-03-01      183738   1260228         1706478     1060860448
# 1 2017-03-02      193763   1270561         1690727     1031846645
# 2 2017-03-03      210479   1248183         1726157     1010867575
# 3 2017-03-04      240061   1492913         1855353     1079194579
# 4 2017-03-05      446314   1594712         2041418     1357736987
# 5 2017-03-06      342997   1330689         1742540     1140228426
# 6 2017-03-07      227313   1363579         1821742     1113811802
# 7 2017-03-08      180313   1353483         1795456     1083475096
# 8 2017-03-09      178800   1345428         1794157     1067636147
# 9 2017-03-10      201180   1344540         1834967     1081234843
#
#    Cricket_match_india  Character_A  day  weekday  weekend  Lag_Views
# 0                    0            0    2        5        0          0
# 1                    0            0    3        6        0     183738
# 2                    0            0    4        7        1     193763
# 3                    1            0    5        1        1     210479
# 4                    0            0    6        2        0     240061
# 5                    0            0    0        3        0     446314
# 6                    0            0    1        4        0     342997
# 7                    0            0    2        5        0     227313
# 8                    0            0    3        6        0     180313
# 9                    0            0    4        7        1     178800

# %% [markdown]
# #### Running fourth model (lm4) visitors, Character_A, Lag_views & weekend

# %%
# Putting feature variable to X
X = media[['Visitors','Character_A','Lag_Views','weekend']]

# Putting response variable to y
y = media['Views_show']

# %%
import statsmodels.api as sm
#Unlike SKLearn, statsmodels don't automatically fit a constant, 
#so you need to use the method sm.add_constant(X) in order to add a constant. 
X = sm.add_constant(X)
# create a fitted model in one line
lm_4 = sm.OLS(y,X).fit()
print(lm_4.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             Views_show   R-squared:                       0.435
# Model:                            OLS   Adj. R-squared:                  0.405
# Method:                 Least Squares   F-statistic:                     14.45
# Date:                Thu, 30 Apr 2020   Prob (F-statistic):           8.61e-09
# Time:                        21:32:56   Log-Likelihood:                -1046.2
# No. Observations:                  80   AIC:                             2102.
# Df Residuals:                      75   BIC:                             2114.
# Df Model:                           4
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# const       -2.891e+05   1.02e+05     -2.821      0.006   -4.93e+05   -8.49e+04
# Visitors        0.2916      0.060      4.839      0.000       0.172       0.412
# Character_A  7.511e+04      3e+04      2.503      0.014    1.53e+04    1.35e+05
# Lag_Views       0.2187      0.102      2.151      0.035       0.016       0.421
# weekend     -2.728e+04   3.29e+04     -0.829      0.410   -9.28e+04    3.83e+04
# ==============================================================================
# Omnibus:                        6.957   Durbin-Watson:                   1.236
# Prob(Omnibus):                  0.031   Jarque-Bera (JB):                7.198
# Skew:                           0.707   Prob(JB):                       0.0273
# Kurtosis:                       2.602   Cond. No.                     1.34e+07
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.34e+07. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
plt.figure(figsize = (20,10))        # Size of the figure
sns.heatmap(media.corr(),annot = True)

# %% [markdown]
# #### Running fifth model (lm5) Character_A, weekend & Views_platform

# %%
# Putting feature variable to X
X = media[['weekend','Character_A','Views_platform']]

# Putting response variable to y
y = media['Views_show']

# %%
import statsmodels.api as sm
#Unlike SKLearn, statsmodels don't automatically fit a constant, 
#so you need to use the method sm.add_constant(X) in order to add a constant. 
X = sm.add_constant(X)
# create a fitted model in one line
lm_5 = sm.OLS(y,X).fit()
print(lm_5.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             Views_show   R-squared:                       0.410
# Model:                            OLS   Adj. R-squared:                  0.387
# Method:                 Least Squares   F-statistic:                     17.61
# Date:                Thu, 30 Apr 2020   Prob (F-statistic):           8.91e-09
# Time:                        21:32:57   Log-Likelihood:                -1048.0
# No. Observations:                  80   AIC:                             2104.
# Df Residuals:                      76   BIC:                             2113.
# Df Model:                           3
# Covariance Type:            nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const          -3.268e+05   1.14e+05     -2.867      0.005   -5.54e+05   -9.97e+04
# weekend        -5.285e+04   3.01e+04     -1.758      0.083   -1.13e+05    7027.278
# Character_A     5.464e+04   3.15e+04      1.737      0.086   -8022.291    1.17e+05
# Views_platform     0.2751      0.053      5.222      0.000       0.170       0.380
# ==============================================================================
# Omnibus:                        3.802   Durbin-Watson:                   0.847
# Prob(Omnibus):                  0.149   Jarque-Bera (JB):                2.998
# Skew:                           0.348   Prob(JB):                        0.223
# Kurtosis:                       2.356   Cond. No.                     1.90e+07
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.9e+07. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# #### Running sixth model (lm6) Character_A, weekend & Visitors

# %%
# Putting feature variable to X
X = media[['weekend','Character_A','Visitors']]

# Putting response variable to y
y = media['Views_show']

# %%
import statsmodels.api as sm
#Unlike SKLearn, statsmodels don't automatically fit a constant, 
#so you need to use the method sm.add_constant(X) in order to add a constant. 
X = sm.add_constant(X)
# create a fitted model in one line
lm_6 = sm.OLS(y,X).fit()
print(lm_6.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             Views_show   R-squared:                       0.400
# Model:                            OLS   Adj. R-squared:                  0.377
# Method:                 Least Squares   F-statistic:                     16.91
# Date:                Thu, 30 Apr 2020   Prob (F-statistic):           1.65e-08
# Time:                        21:32:57   Log-Likelihood:                -1048.6
# No. Observations:                  80   AIC:                             2105.
# Df Residuals:                      76   BIC:                             2115.
# Df Model:                           3
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# const       -2.548e+05   1.04e+05     -2.459      0.016   -4.61e+05   -4.84e+04
# weekend     -5.843e+04   3.02e+04     -1.931      0.057   -1.19e+05    1820.667
# Character_A  9.645e+04    2.9e+04      3.327      0.001    3.87e+04    1.54e+05
# Visitors        0.3092      0.061      5.058      0.000       0.187       0.431
# ==============================================================================
# Omnibus:                        4.095   Durbin-Watson:                   0.942
# Prob(Omnibus):                  0.129   Jarque-Bera (JB):                3.677
# Skew:                           0.444   Prob(JB):                        0.159
# Kurtosis:                       2.438   Cond. No.                     1.30e+07
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.3e+07. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# #### Running seventh model (lm7) Character_A, weekend, Visitors & Ad_impressions

# %%
# Putting feature variable to X
X = media[['weekend','Character_A','Visitors','Ad_impression']]

# Putting response variable to y
y = media['Views_show']

# %%
import statsmodels.api as sm
#Unlike SKLearn, statsmodels don't automatically fit a constant, 
#so you need to use the method sm.add_constant(X) in order to add a constant. 
X = sm.add_constant(X)
# create a fitted model in one line
lm_7 = sm.OLS(y,X).fit()
print(lm_7.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             Views_show   R-squared:                       0.665
# Model:                            OLS   Adj. R-squared:                  0.647
# Method:                 Least Squares   F-statistic:                     37.21
# Date:                Thu, 30 Apr 2020   Prob (F-statistic):           4.04e-17
# Time:                        21:32:58   Log-Likelihood:                -1025.3
# No. Observations:                  80   AIC:                             2061.
# Df Residuals:                      75   BIC:                             2073.
# Df Model:                           4
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const         -5.156e+05    8.5e+04     -6.065      0.000   -6.85e+05   -3.46e+05
# weekend        1.599e+04   2.47e+04      0.647      0.520   -3.33e+04    6.53e+04
# Character_A   -5.289e+04   2.92e+04     -1.811      0.074   -1.11e+05    5273.870
# Visitors          0.1224      0.052      2.353      0.021       0.019       0.226
# Ad_impression     0.0004   5.52e-05      7.696      0.000       0.000       0.001
# ==============================================================================
# Omnibus:                        6.744   Durbin-Watson:                   0.777
# Prob(Omnibus):                  0.034   Jarque-Bera (JB):                6.978
# Skew:                           0.716   Prob(JB):                       0.0305
# Kurtosis:                       2.792   Cond. No.                     1.23e+10
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.23e+10. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# #### Running eight model (lm8) Character_A, weekend & Ad_impressions

# %%
# Putting feature variable to X
X = media[['weekend','Character_A','Ad_impression']]

# Putting response variable to y
y = media['Views_show']

# %%
import statsmodels.api as sm
#Unlike SKLearn, statsmodels don't automatically fit a constant, 
#so you need to use the method sm.add_constant(X) in order to add a constant. 
X = sm.add_constant(X)
# create a fitted model in one line
lm_8 = sm.OLS(y,X).fit()
print(lm_8.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             Views_show   R-squared:                       0.640
# Model:                            OLS   Adj. R-squared:                  0.626
# Method:                 Least Squares   F-statistic:                     45.07
# Date:                Thu, 30 Apr 2020   Prob (F-statistic):           7.65e-17
# Time:                        21:32:58   Log-Likelihood:                -1028.2
# No. Observations:                  80   AIC:                             2064.
# Df Residuals:                      76   BIC:                             2074.
# Df Model:                           3
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const         -3.933e+05   6.93e+04     -5.678      0.000   -5.31e+05   -2.55e+05
# weekend        2.459e+04   2.52e+04      0.977      0.332   -2.56e+04    7.47e+04
# Character_A   -6.402e+04   2.97e+04     -2.159      0.034   -1.23e+05   -4953.626
# Ad_impression     0.0005   5.03e-05      9.659      0.000       0.000       0.001
# ==============================================================================
# Omnibus:                        8.845   Durbin-Watson:                   0.865
# Prob(Omnibus):                  0.012   Jarque-Bera (JB):                8.636
# Skew:                           0.783   Prob(JB):                       0.0133
# Kurtosis:                       3.370   Cond. No.                     1.01e+10
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.01e+10. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
#Ad impression in million
media['ad_impression_million'] = media['Ad_impression']/1000000

# %% [markdown]
# #### Running seventh model (lm7) Character_A, weekend, Visitors, ad_impressions_million & Cricket_match_india

# %%
# Putting feature variable to X
X = media[['weekend','Character_A','ad_impression_million','Cricket_match_india']]

# Putting response variable to y
y = media['Views_show']

# %%
import statsmodels.api as sm
#Unlike SKLearn, statsmodels don't automatically fit a constant, 
#so you need to use the method sm.add_constant(X) in order to add a constant. 
X = sm.add_constant(X)
# create a fitted model in one line
lm_9 = sm.OLS(y,X).fit()
print(lm_9.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             Views_show   R-squared:                       0.640
# Model:                            OLS   Adj. R-squared:                  0.621
# Method:                 Least Squares   F-statistic:                     33.39
# Date:                Thu, 30 Apr 2020   Prob (F-statistic):           5.52e-16
# Time:                        21:32:59   Log-Likelihood:                -1028.2
# No. Observations:                  80   AIC:                             2066.
# Df Residuals:                      75   BIC:                             2078.
# Df Model:                           4
# Covariance Type:            nonrobust
# =========================================================================================
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# const                  -3.94e+05   6.98e+04     -5.645      0.000   -5.33e+05   -2.55e+05
# weekend                2.419e+04   2.54e+04      0.951      0.344   -2.65e+04    7.48e+04
# Character_A           -6.269e+04   3.06e+04     -2.051      0.044   -1.24e+05   -1804.230
# ad_impression_million   485.1113     50.604      9.586      0.000     384.303     585.919
# Cricket_match_india    7439.0643   3.69e+04      0.202      0.841   -6.61e+04    8.09e+04
# ==============================================================================
# Omnibus:                        8.519   Durbin-Watson:                   0.863
# Prob(Omnibus):                  0.014   Jarque-Bera (JB):                8.280
# Skew:                           0.770   Prob(JB):                       0.0159
# Kurtosis:                       3.336   Cond. No.                     1.01e+04
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.01e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# #### Running seventh model (lm7) Character_A, weekend & ad_impressions_million

# %%
# Putting feature variable to X
X = media[['weekend','Character_A','ad_impression_million']]

# Putting response variable to y
y = media['Views_show']

# %%
import statsmodels.api as sm
#Unlike SKLearn, statsmodels don't automatically fit a constant, 
#so you need to use the method sm.add_constant(X) in order to add a constant. 
X = sm.add_constant(X)
# create a fitted model in one line
lm_10 = sm.OLS(y,X).fit()
print(lm_10.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             Views_show   R-squared:                       0.640
# Model:                            OLS   Adj. R-squared:                  0.626
# Method:                 Least Squares   F-statistic:                     45.07
# Date:                Thu, 30 Apr 2020   Prob (F-statistic):           7.65e-17
# Time:                        21:32:59   Log-Likelihood:                -1028.2
# No. Observations:                  80   AIC:                             2064.
# Df Residuals:                      76   BIC:                             2074.
# Df Model:                           3
# Covariance Type:            nonrobust
# =========================================================================================
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# const                 -3.933e+05   6.93e+04     -5.678      0.000   -5.31e+05   -2.55e+05
# weekend                2.459e+04   2.52e+04      0.977      0.332   -2.56e+04    7.47e+04
# Character_A           -6.402e+04   2.97e+04     -2.159      0.034   -1.23e+05   -4953.626
# ad_impression_million   485.4410     50.257      9.659      0.000     385.345     585.537
# ==============================================================================
# Omnibus:                        8.845   Durbin-Watson:                   0.865
# Prob(Omnibus):                  0.012   Jarque-Bera (JB):                8.636
# Skew:                           0.783   Prob(JB):                       0.0133
# Kurtosis:                       3.370   Cond. No.                     1.01e+04
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.01e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# #### Making predictions using lm10

# %%
# Making predictions using the model
X = media[['weekend','Character_A','ad_impression_million']]
X = sm.add_constant(X)
Predicted_views = lm_10.predict(X)

# %%
from sklearn.metrics import mean_squared_error, r2_score
mse = mean_squared_error(media.Views_show, Predicted_views)
r_squared = r2_score(media.Views_show, Predicted_views)

# %%
print('Mean_Squared_Error :' ,mse)
print('r_square_value :',r_squared)
# Out:
# Mean_Squared_Error : 8527977939.606975
# r_square_value : 0.6401928853385604

# %%
#Actual vs Predicted
c = [i for i in range(1,81,1)]
fig = plt.figure()
plt.plot(c,media.Views_show, color="blue", linewidth=2.5, linestyle="-")
plt.plot(c,Predicted_views, color="red",  linewidth=2.5, linestyle="-")
fig.suptitle('Actual and Predicted', fontsize=20)              # Plot heading 
plt.xlabel('Index', fontsize=18)                               # X-label
plt.ylabel('Views', fontsize=16)                               # Y-label
# Out:
# Text(0, 0.5, 'Views')

# %%
# Error terms
c = [i for i in range(1,81,1)]
fig = plt.figure()
plt.plot(c,media.Views_show-Predicted_views, color="blue", linewidth=2.5, linestyle="-")
fig.suptitle('Error Terms', fontsize=20)              # Plot heading 
plt.xlabel('Index', fontsize=18)                      # X-label
plt.ylabel('Views_show-Predicted_views', fontsize=16)                # Y-label
# Out:
# Text(0, 0.5, 'Views_show-Predicted_views')

# %% [markdown]
# #### Making predictions using lm6

# %%
# Making predictions using the model
X = media[['weekend','Character_A','Visitors']]
X = sm.add_constant(X)
Predicted_views = lm_6.predict(X)

# %%
from sklearn.metrics import mean_squared_error, r2_score
mse = mean_squared_error(media.Views_show, Predicted_views)
r_squared = r2_score(media.Views_show, Predicted_views)

# %%
print('Mean_Squared_Error :' ,mse)
print('r_square_value :',r_squared)
# Out:
# Mean_Squared_Error : 14213238693.35622
# r_square_value : 0.40032391729117

# %%
#Actual vs Predicted
c = [i for i in range(1,81,1)]
fig = plt.figure()
plt.plot(c,media.Views_show, color="blue", linewidth=2.5, linestyle="-")
plt.plot(c,Predicted_views, color="red",  linewidth=2.5, linestyle="-")
fig.suptitle('Actual and Predicted', fontsize=20)              # Plot heading 
plt.xlabel('Index', fontsize=18)                               # X-label
plt.ylabel('Views', fontsize=16)                               # Y-label
# Out:
# Text(0, 0.5, 'Views')

# %%
# Error terms
c = [i for i in range(1,81,1)]
fig = plt.figure()
plt.plot(c,media.Views_show-Predicted_views, color="blue", linewidth=2.5, linestyle="-")
fig.suptitle('Error Terms', fontsize=20)              # Plot heading 
plt.xlabel('Index', fontsize=18)                      # X-label
plt.ylabel('Views_show-Predicted_views', fontsize=16)                # Y-label
# Out:
# Text(0, 0.5, 'Views_show-Predicted_views')
